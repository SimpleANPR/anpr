# %%
from anpr.generic.filter_mean import FilterMean
from anpr.datasets.open_alpr import OpenALPRDataset

from matplotlib import pyplot as plt

# %%
ds = OpenALPRDataset()
img = ds.image_at(20).image
plt.imshow(img)

# %%
mean_filter = FilterMean(17)
plt.imshow(mean_filter.process(img))

# %%
img2 = ds.image_at(21).image
plt.imshow(img2)
img2.shape
# Out:
# (1280, 1280, 3)

# %%
from anpr.interpolation.bilinear import Bilinear

bilinear  = Bilinear(target_resolution=(2480,2480))
plt.imshow(bilinear.process(img2))
