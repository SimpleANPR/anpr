# %%
from anpr.datasets.open_alpr import OpenALPRDataset
from matplotlib import pyplot as plt

# %%
ds = OpenALPRDataset()
# Out:
# Cached Downloading: img/open_alpr/data.zip
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1pOCgNkgLu8xCskxiFHGSzDIp8ltdHtuG
# From (redirected): https://drive.google.com/uc?id=1pOCgNkgLu8xCskxiFHGSzDIp8ltdHtuG&confirm=t&uuid=6207483f-2b44-4f37-bd14-fdf605805732
# To: /home/moesiof/.cache/gdown/tmpnnw_10_r/dl
# 100%|██████████| 119M/119M [00:05<00:00, 21.2MB/s]

# %%
plt.imshow(ds.image_at(100).image)

# %%
ds.image_at(100).plate_text
# Out:
# 'PJF4224'
